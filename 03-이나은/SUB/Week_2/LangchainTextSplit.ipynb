# %%
from langchain_text_splitters import (
    Language,
    RecursiveCharacterTextSplitter,
)

# %%
# 지원되는 언어의 전체 목록을 가져옵니다.
[e.value for e in Language]
# Out:
# ['cpp',
#  'go',
#  'java',
#  'kotlin',
#  'js',
#  'ts',
#  'php',
#  'proto',
#  'python',
#  'rst',
#  'ruby',
#  'rust',
#  'scala',
#  'swift',
#  'markdown',
#  'latex',
#  'html',
#  'sol',
#  'csharp',
#  'cobol',
#  'c',
#  'lua',
#  'perl',
#  'haskell',
#  'elixir',
#  'powershell']

# %%
# 주어진 언어에 대해 사용되는 구분자를 확인할 수 있습니다.
RecursiveCharacterTextSplitter.get_separators_for_language(Language.PYTHON)
# Out:
# ['\nclass ', '\ndef ', '\n\tdef ', '\n\n', '\n', ' ', '']

# %%
PYTHON_CODE = """

def hello_world():
  print("Hello World")

hello world()
"""

python_splitter = RecursiveCharacterTextSplitter.from_language(
    language = Language.PYTHON,
    chunk_size = 50,
    chunk_overlap = 0
)

# %%
python_docs = python_splitter.create_documents([PYTHON_CODE])
python_docs
# Out:
# [Document(metadata={}, page_content='def hello_world():\n  print("Hello World")'),
#  Document(metadata={}, page_content='hello world()')]

# %%
for doc in python_docs:
  print(doc.page_content, end = "==============================\n")
# Out:
# def hello_world():
#   print("Hello World")==============================
# hello world()==============================

# %% [markdown]
# # JS

# %%
JS_CODE = """
function helloWorld() {
  console.log("Hello, World!");
}

helloWorld();
"""

js_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.JS, chunk_size=60, chunk_overlap=0
)

js_docs = js_splitter.create_documents([JS_CODE])
js_docs
# Out:
# [Document(metadata={}, page_content='function helloWorld() {\n  console.log("Hello, World!");\n}'),
#  Document(metadata={}, page_content='helloWorld();')]

# %% [markdown]
# # Markdown

# %%
html_text = """
<!DOCTYPE html>
<html>
    <head>
        <title>전주대학교 인공지능학과 소개</title>
        <style>
            body {
                font-family: Arial, sans-serif;
            }
            h1 {
                color: pink;
            }
            h2 {
                color: green;
            }
            p {
                line-height: 1.6;
            }
            ul {
                margin: 20px;
                padding-left: 40px;
            }
        </style>
    </head>
    <body>
        <div>
            <h1>전주대학교 인공지능학과</h1>
            <p>전주대학교 인공지능학과는 차세대 기술 혁신을 이끄는 인재를 양성하기 위해 설립되었습니다. 본 학과는 최신 기술 트렌드와 산업 요구를 반영하여 이론과 실습을 겸비한 교육을 제공합니다.</p>
        </div>
        <div>
            <h2>학과 소개</h2>
            <p>인공지능학과에서는 다양한 응용 분야에서 사용할 수 있는 기초 및 심화 AI 기술을 교육하며, 산업체와 협력하여 실질적인 문제 해결 능력을 배양합니다.</p>
        </div>
        <div>
            <h2>교육 목표</h2>
            <ul>
                <li>기초 AI 이론 및 기술 이해</li>
                <li>머신러닝 및 딥러닝 기술 습득</li>
                <li>실제 산업 문제 해결 능력 함양</li>
                <li>창의적이고 윤리적인 AI 전문가 양성</li>
            </ul>
        </div>
        <div>
            <h2>주요 프로그램</h2>
            <p>전주대학교 인공지능학과는 다양한 프로그램과 프로젝트를 통해 학생들이 실무 능력을 기를 수 있는 기회를 제공합니다. 또한, 국내외 연구기관 및 기업과의 협력을 통해 산업현장 경험을 쌓을 수 있도록 지원합니다.</p>
        </div>
    </body>
</html>
"""

# %%
html_splitter = RecursiveCharacterTextSplitter.from_language(
    # HTML 언어를 사용하여 텍스트 분할기 생성
    language=Language.HTML,
    # 청크 크기를 60으로 설정
    chunk_size=60,
    # 청크 간 중복되는 부분이 없도록 설정
    chunk_overlap=0,
)
# 주어진 HTML 텍스트를 분할하여 문서 생성
html_docs = html_splitter.create_documents([html_text])
# 생성된 문서 출력
html_docs
# Out:
# [Document(metadata={}, page_content='<!DOCTYPE html>\n<html>'),
#  Document(metadata={}, page_content='<head>\n        <title>전주대학교 인공지능학과 소개</title>'),
#  Document(metadata={}, page_content='<style>\n            body {\n                font-family: Aria'),
#  Document(metadata={}, page_content='l, sans-serif;  \n            }\n            h1 {'),
#  Document(metadata={}, page_content='color: pink;\n            }\n            h2 {'),
#  Document(metadata={}, page_content='color: green;\n            }\n            p {'),
#  Document(metadata={}, page_content='line-height: 1.6;\n            }\n            ul {'),
#  Document(metadata={}, page_content='margin: 20px;\n                padding-left: 40px;'),
#  Document(metadata={}, page_content='}\n        </style>\n    </head>'),
#  Document(metadata={}, page_content='<body>'),
#  Document(metadata={}, page_content='<div>\n            <h1>전주대학교 인공지능학과</h1>'),
#  Document(metadata={}, page_content='<p>전주대학교 인공지능학과는 차세대 기술 혁신을 이끄는 인재를 양성하기 위해 설립되었습니다. 본 학과는 최'),
#  Document(metadata={}, page_content='신 기술 트렌드와 산업 요구를 반영하여 이론과 실습을 겸비한 교육을 제공합니다.</p>\n        </d'),
#  Document(metadata={}, page_content='iv>'),
#  Document(metadata={}, page_content='<div>\n            <h2>학과 소개</h2>'),
#  Document(metadata={}, page_content='<p>인공지능학과에서는 다양한 응용 분야에서 사용할 수 있는 기초 및 심화 AI 기술을 교육하며, 산업체와'),
#  Document(metadata={}, page_content='협력하여 실질적인 문제 해결 능력을 배양합니다.</p>\n        </div>'),
#  Document(metadata={}, page_content='<div>'),
#  Document(metadata={}, page_content='<h2>교육 목표</h2>\n            <ul>'),
#  Document(metadata={}, page_content='<li>기초 AI 이론 및 기술 이해</li>'),
#  Document(metadata={}, page_content='<li>머신러닝 및 딥러닝 기술 습득</li>'),
#  Document(metadata={}, page_content='<li>실제 산업 문제 해결 능력 함양</li>'),
#  Document(metadata={}, page_content='<li>창의적이고 윤리적인 AI 전문가 양성</li>\n            </ul>\n        </di'),
#  Document(metadata={}, page_content='v>'),
#  Document(metadata={}, page_content='<div>\n            <h2>주요 프로그램</h2>'),
#  Document(metadata={}, page_content='<p>전주대학교 인공지능학과는 다양한 프로그램과 프로젝트를 통해 학생들이 실무 능력을 기를 수 있는 기회를'),
#  Document(metadata={}, page_content='제공합니다. 또한, 국내외 연구기관 및 기업과의 협력을 통해 산업현장 경험을 쌓을 수 있도록 지원합니다.</'),
#  Document(metadata={}, page_content='p>\n        </div>\n    </body>\n</html>')]

# %%
pip install --upgrade langchain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.12)
# Collecting langchain
#   Downloading langchain-0.3.13-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.11.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.26 (from langchain)
#   Downloading langchain_core-0.3.28-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.3)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.10.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.2.2)
# Downloading langchain-0.3.13-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.9 MB/s eta 0:00:00
# Downloading langchain_core-0.3.28-py3-none-any.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 16.5 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.25
#     Uninstalling langchain-core-0.3.25:
#       Successfully uninstalled langchain-core-0.3.25
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.12
#     Uninstalling langchain-0.3.12:
#       Successfully uninstalled langchain-0.3.12
# Successfully installed langchain-0.3.13 langchain-core-0.3.28

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 파일 객체 생성 및 내용을 읽어서 변수에 저장
with open('/content/html_jju.txt', 'r', encoding='utf-8') as f:
    file_content = f.read()

# HTML 언어를 사용하여 텍스트 분할기 생성
html_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.HTML,
    chunk_size=60,  # 청크 크기를 60으로 설정
    chunk_overlap=0  # 청크 간 중복되는 부분이 없도록 설정
)

# 주어진 HTML 텍스트를 분할하여 문서 생성
html_docs = html_splitter.create_documents([file_content])

# 생성된 문서 출력
for doc in html_docs:
    print(doc)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# page_content='프로그램안내"
#
#
# 												>'
# page_content='보안프로그램안내
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/security/sw-01.jsp"'
# page_content='title="소프트웨어/저작권"'
# page_content='>
# 													소프트웨어'
# page_content='/저작권
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/security/guidelines-02.jsp"'
# page_content='title="관련 자'
# page_content='료"
#
#
# 												>
# 													관'
# page_content='련 자료
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/smartjj/wired.jsp"'
# page_content='title="네트워크/'
# page_content='통신"
#
#
# 							>
# 								네트워크/통신
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/wired.jsp"'
# page_content='title="유선랜"'
# page_content='>
# 													유선랜
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/wireless.jsp"'
# page_content='title="무선랜"'
# page_content='>
# 													무선랜
# 												<'
# page_content='/a>
# 											</li>
#
#
# 								</ul>'
# page_content='</li>'
# page_content='<li class="">
#
# 							<a href="/jj/smartjj/homepage.j'
# page_content='sp"
#
#
#
#
# 										title="홈페'
# page_content='이지"
#
#
# 							>
# 								홈페이지
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/homepage.jsp"'
# page_content='title="홈페이지 광장"'
# page_content='>
# 													홈페이지 광장'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/domain.jsp"'
# page_content='title="도메인 신청"'
# page_content='>
# 													도메인 신청'
# page_content='</a>
# 											</li>
#
#
# 								</ul'
# page_content='>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/smartjj/phone.jsp"'
# page_content='title="정보조회서'
# page_content='비스"
#
#
# 							>
# 								정보조회서비스
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/profinfo.jsp"'
# page_content='title="교수 인명록"'
# page_content='>
# 													교수 인명록'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/post.jsp"'
# page_content='title="교내 우편물 조회"'
# page_content='>
# 													교내 우편물 조회'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>
#
#
#
# 			</ul>
#
#
# 		</li>'
# page_content='</ul>
#
#
#
#
# 						</d'
# page_content='iv>'
# page_content='<div class="slideMenu">'
# page_content='<ul class="depth01">'
# page_content='<li class="">
#
# 					<a href="/jj/introduction/greetings.jsp"'
# page_content='title="학교안내"
#
#
# 			>'
# page_content='학교안내
# 			</a>'
# page_content='<ul class="depth02">'
# page_content='<li class="">
#
# 							<a href="/jj/introduction/greet'
# page_content='ings.jsp"
#
#
#
#
# 										tit'
# page_content='le="학교소개"
#
#
# 							>
# 								학교소개
# 							</'
# page_content='a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/greetings.jsp"'
# page_content='title="총장소개"'
# page_content='>
# 													총장소개'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/movements.jsp"'
# page_content='title="총장동정"'
# page_content='>
# 													총장동정'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/indicator.jsp"'
# page_content='title="교육지표"'
# page_content='>
# 													교육지표'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/vision/jjvision.jsp"'
# page_content='title="비전"'
# page_content='>
# 													비전'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/christianity.jsp"'
# page_content='title="신앙고백문"'
# page_content='>
# 													신앙고백문'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/history.jsp"'
# page_content='title="연혁"'
# page_content='>
# 													연혁'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/organization.jsp"'
# page_content='title="조직도"'
# page_content='>
# 													조직도'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/stat.jsp"'
# page_content='title="현황"'
# page_content='>
# 													현황
# 												</'
# page_content='a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/rule.jsp"'
# page_content='title="규정"'
# page_content='>
# 													규정
# 												</'
# page_content='a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/budget.jsp"'
# page_content='title="예결산공고"'
# page_content='>
# 													예결산공고'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/meeting.jsp"'
# page_content='title="회의안내 및 회의록"'
# page_content='>
# 													회의안내 및'
# page_content='회의록
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/revision.jsp"'
# page_content='title="학칙 등 개정(안)"'
# page_content='>
# 													학칙 등'
# page_content='개정(안)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/expense.jsp"'
# page_content='title="업무추진비"'
# page_content='>
# 													업무추진비'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/foundation/greetings.jsp"'
# page_content='title="학'
# page_content='교법인"
#
#
# 												>'
# page_content='학교법인
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/domestic.jsp"'
# page_content='title="교류/협력"'
# page_content='>
# 													교류/협력'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/introduction/offic'
# page_content='e/president.jsp"'
# page_content='title="부서/기관"
#
#
# 							>
# 								부서/기관'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/office/president.jsp"'
# page_content='title="본부"'
# page_content='>
# 													본부'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/office/affiliate1.jsp"'
# page_content='title="부속기관'
# page_content='"
#
#
# 												>
# 													부속'
# page_content='기관
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/office/sanhak.jsp"'
# page_content='title="사업단"'
# page_content='>
# 													사업단'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/introduction/symbo'
# page_content='l/symbol.jsp"'
# page_content='title="전주대상징"
#
#
# 							>
# 								전주대상징'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/symbol/symbol.jsp"'
# page_content='title="상징"'
# page_content='>
# 													상징'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/symbol/slogan.jsp"'
# page_content='title="슬로건"'
# page_content='>
# 													슬로건'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/symbol/schoolsong.jsp"'
# page_content='title="교가"'
# page_content='>
# 													교가'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/symbol/ui.jsp"'
# page_content='title="전주대UI"'
# page_content='>
# 													전주대UI'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/introduction/facil'
# page_content='ity-rent.jsp"'
# page_content='title="학교시설"
#
#
# 							>
# 								학교시설'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/facility-rent.jsp"'
# page_content='title="대관안내"'
# page_content='>
# 													대관안내'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/facility.jsp"'
# page_content='title="시설안내"'
# page_content='>
# 													시설안내'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/community/news/jjn'
# page_content='ews.jsp"
#
#
#
#
# 										titl'
# page_content='e="JJ미디어"
#
#
# 							>
# 								JJ미디어
# 							<'
# page_content='/a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/news/jjnews.jsp"'
# page_content='title="JJ뉴스"'
# page_content='>
# 													JJ뉴스'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/pr/article.jsp"'
# page_content='title="언론에 비친 전주대"'
# page_content='>
# 													언론에'
# page_content='비친 전주대
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/pr/hotclick.jsp"'
# page_content='title="뉴스레터(Hot C'
# page_content='lick)"
#
#
# 												>'
# page_content='뉴스레터(Hot Click)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/pr/design.jsp"'
# page_content='title="디자인"'
# page_content='>
# 													디자인'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/pr/gallery.jsp"'
# page_content='title="사진자료"'
# page_content='>
# 													사진자료'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/pr/video.jsp"'
# page_content='title="홍보영상"'
# page_content='>
# 													홍보영상'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/pr/sns.jsp"'
# page_content='title="소셜 미디어"'
# page_content='>
# 													소셜 미디어'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"https://www.jj.ac.kr/jjnews/"'
# page_content='target="_blank"'
# page_content='title="전주대 신문 (새창열림)" rel="noopener noreferrer'
# page_content='"'
# page_content='>
# 													전주대 신문
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/pr/promotion.jsp"'
# page_content='title="홍보요청"'
# page_content='>
# 													홍보요청'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/introduction/map.j'
# page_content='sp"
#
#
#
#
# 										title="캠퍼'
# page_content='스안내"
#
#
# 							>
# 								캠퍼스안내
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/map.jsp"'
# page_content='title="캠퍼스맵"'
# page_content='>
# 													캠퍼스맵'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"https://www.jj.ac.kr/vr/index.html"'
# page_content='target="_blank"'
# page_content='title="VR투어 (새창열림)" rel="noopener norefe'
# page_content='rrer"'
# page_content='>
# 													VR투어
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/introduction/location.jsp"'
# page_content='title="오시는길"'
# page_content='>
# 													오시는길'
# page_content='</a>
# 											</li>
#
#
# 								<'
# page_content='/ul>
#
# 						</li>
#
#
#
# 			</ul>
#
#
# 		</li>'
# page_content='<li class="">
#
# 					<a href="http://iphak.jj.ac.kr"'
# page_content='target="_blank"
#
#
# 							title="입학정보 ('
# page_content='새창열림)" rel="noopener noreferrer"'
# page_content='>
#
# 				입학정보
# 			</a>'
# page_content='<ul class="depth02">'
# page_content='<li class="">
#
# 							<a href="http://iphak.jj.ac.kr"'
# page_content='target="_blank"'
# page_content='title="대학 입학정보 (새창열림)" rel="noopener noref'
# page_content='errer"
#
#
#
#
#
# 							>'
# page_content='대학 입학정보
# 							</a>
#
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/admission/freshman'
# page_content='.jsp"
#
#
#
#
# 										target="_blank"'
# page_content='title="신(편)입생 길잡이 (새창열림)" rel="noopen'
# page_content='er noreferrer"'
# page_content='>
# 								신(편)입생 길잡이
# 							</a>
#
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="https://www.jj.ac.kr/g'
# page_content='raduate/apply/special.jsp"'
# page_content='target="_blank"
#
#
# 											title="대학원 입학정보'
# page_content='(새창열림)" rel="noopener noreferrer"'
# page_content='>
# 								대학원 입학정보
# 							</a>'
# page_content='</li>
#
#
#
# 			</ul>
#
#
# 		</li>'
# page_content='<li class="">
#
# 					<a href="/jj/colleges/all.jsp"'
# page_content='title="대학/대학원"
#
#
# 			>
#
# 				대학/대'
# page_content='학원
# 			</a>'
# page_content='<ul class="depth02">'
# page_content='<li class="">
#
# 							<a href="/jj/colleges/all.jsp"'
# page_content='title="대학"'
# page_content='>
# 								대학
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/all.jsp"'
# page_content='title="대학소개"'
# page_content='>
# 													대학소개
# 												</a'
# page_content='>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/human/01.jsp"'
# page_content='title="인문콘텐츠대학"'
# page_content='>
# 													인문콘텐츠대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/social/01.jsp"'
# page_content='title="사회과학대학"'
# page_content='>
# 													사회과학대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/biz/01.jsp"'
# page_content='title="경영대학"'
# page_content='>
# 													경영대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/med/01.jsp"'
# page_content='title="의과학대학"'
# page_content='>
# 													의과학대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/engin/01.jsp"'
# page_content='title="공과대학"'
# page_content='>
# 													공과대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/software/01.jsp"'
# page_content='title="소프트웨어융합대학"'
# page_content='>
# 													소프트웨어융합'
# page_content='대학
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/cc/01.jsp"'
# page_content='title="문화융합대학"'
# page_content='>
# 													문화융합대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/ct/01.jsp"'
# page_content='title="문화관광대학"'
# page_content='>
# 													문화관광대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/edu/01.jsp"'
# page_content='title="사범대학"'
# page_content='>
# 													사범대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/future/01.jsp"'
# page_content='title="미래융합대학"'
# page_content='>
# 													미래융합대학'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/superstar/01.jsp"'
# page_content='title="수퍼스타칼리지"'
# page_content='>
# 													수퍼스타칼리지'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="http://www.jj.ac.kr/gr'
# page_content='aduate"
#
#
#
#
# 										target="_blank'
# page_content='"
#
#
# 											title="대학원 (새창열림)" rel="noopener no'
# page_content='referrer"
#
#
#
#
#
# 							>'
# page_content='대학원
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://www.jj.ac.kr/graduate"'
# page_content='target="_blank"'
# page_content='title="일반대학원 (새창열림)" rel="noopener noreferrer"'
# page_content='>
# 													일반대학원
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/grad/05.jsp"'
# page_content='title="선교신학대학원"'
# page_content='>
# 													선교신학대학원'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/colleges/grad/01.jsp"'
# page_content='title="특수대학원"'
# page_content='>
# 													특수대학원'
# page_content='</a>
# 											</li>
#
#
# 								</ul'
# page_content='>
#
# 						</li>
#
#
#
# 			</ul>
#
#
# 		</li>'
# page_content='<li class="">
#
# 					<a href="/jj/campuslife/schedule.jsp?mod'
# page_content='e=include&amp;include=table"
#
#
#
#
# 						ti'
# page_content='tle="대학생활"
#
#
# 			>
#
# 				대학생활
# 			</a>'
# page_content='<ul class="depth02">'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/schedul'
# page_content='e.jsp?mode=include&amp;include=table"'
# page_content='title="학사일정"'
# page_content='>
# 								학사일정
# 							</a>
#
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/haksasy'
# page_content='stem.jsp"
#
#
#
#
# 										tit'
# page_content='le="학사안내"
#
#
# 							>
# 								학사안내
# 							</'
# page_content='a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/haksasystem.jsp"'
# page_content='title="학사제도안내"'
# page_content='>
# 													학사제도안내'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/haksapds.jsp"'
# page_content='title="학사자료실(편람)"'
# page_content='>
# 													학사자료실(편람'
# page_content=')
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/scholar'
# page_content='ship.jsp"
#
#
#
#
# 										tit'
# page_content='le="장학/학자금"
#
#
# 							>
# 								장학/학자금'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/scholarship.jsp"'
# page_content='title="장학(교내)"'
# page_content='>
# 													장학(교내)'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/scholarship2.jsp"'
# page_content='title="장학(교외)"'
# page_content='>
# 													장학(교외)'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/loan.jsp"'
# page_content='title="학자금대출"'
# page_content='>
# 													학자금대출'
# page_content='</a>
# 											</li>
#
#
# 								</ul>'
# page_content='</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/registr'
# page_content='ation/document.jsp"'
# page_content='title="등록"
#
#
# 							>
# 								등록'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/registration/document.jsp"'
# page_content='title="등록'
# page_content='금 바로가기"
#
#
# 												>'
# page_content='등록금 바로가기
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/registration/info.jsp"'
# page_content='title="등록안내"'
# page_content='>
# 													등록안내'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/registration/notice.jsp"'
# page_content='title="공지사항'
# page_content='(등록)"
#
#
# 												>'
# page_content='공지사항(등록)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/registration/tel.jsp"'
# page_content='title="문의전화"'
# page_content='>
# 													문의전화'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/volunte'
# page_content='er.jsp"
#
#
#
#
# 										title'
# page_content='="사회봉사"
#
#
# 							>
# 								사회봉사
# 							</a>'
# page_content='</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/bus/inf'
# page_content='o.jsp"
#
#
#
#
# 										title='
# page_content='"통학버스/교통"
#
#
# 							>
# 								통학버스/교통'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/bus/info.jsp"'
# page_content='title="통학버스"'
# page_content='>
# 													통학버스'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/bus/seoul.jsp"'
# page_content='title="서울남부터미널직통버스"'
# page_content='>
# 													서울남부터'
# page_content='미널직통버스
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/welfare'
# page_content='.jsp"
#
#
#
#
# 										title="'
# page_content='후생복지"
#
#
# 							>
# 								후생복지
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/welfare.jsp"'
# page_content='title="복지/편의시설"'
# page_content='>
# 													복지/편의시설'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/welfare/health.jsp"'
# page_content='title="보건진료소"'
# page_content='>
# 													보건진료소'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/welfare/insurance.jsp"'
# page_content='title="학생상해보험'
# page_content='"
#
#
# 												>
# 													학생'
# page_content='상해보험
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/welfare/food.jsp"'
# page_content='title="식단조회"'
# page_content='>
# 													식단조회'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/dormito'
# page_content='ry/info.jsp"'
# page_content='title="학생생활관(기숙사)"
#
#
# 							>
# 								학생생활관'
# page_content='(기숙사)
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/dormitory/info.jsp"'
# page_content='title="이용안내"'
# page_content='>
# 													이용안내'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/dormitory/join.jsp"'
# page_content='title="입사안내"'
# page_content='>
# 													입사안내'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/union.j'
# page_content='sp"
#
#
#
#
# 										title="학생'
# page_content='자치기구"
#
#
# 							>
# 								학생자치기구
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/union.jsp"'
# page_content='title="총학생회"'
# page_content='>
# 													총학생회'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/club.jsp"'
# page_content='title="중앙동아리연합회"'
# page_content='>
# 													중앙동아리연합회'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/library.jsp"'
# page_content='title="도서관자치위원회"'
# page_content='>
# 													도서관자치위원회'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/rotc.js'
# page_content='p"
#
#
#
#
# 										title="학군단'
# page_content='"
#
#
# 							>
# 								학군단
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/rotc.jsp"'
# page_content='title="학군사관후보생(ROTC)"'
# page_content='>
# 													학군사관후보생('
# page_content='ROTC)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/officer.jsp"'
# page_content='title="학사예비장교후보생"'
# page_content='>
# 													학사예비장교후보생'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/armyscholar.jsp"'
# page_content='title="학사사관"'
# page_content='>
# 													학사사관'
# page_content='</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/defense'
# page_content='/01.jsp"
#
#
#
#
# 										titl'
# page_content='e="직장예비군연대"
#
#
# 							>
# 								직장예비군연대'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/defense/01.jsp"'
# page_content='title="병무행정 안내"'
# page_content='>
# 													병무행정 안내'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/defense/02-01.jsp"'
# page_content='title="예비군"'
# page_content='>
# 													예비군'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/defense/03.jsp"'
# page_content='title="직장 민방위대 안내"'
# page_content='>
# 													직장 민방'
# page_content='위대 안내
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/defense/04.jsp"'
# page_content='title="공지사항/질의응답"'
# page_content='>
# 													공지사항/질'
# page_content='의응답
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/campuslife/monitor'
# page_content='/01.jsp"
#
#
#
#
# 										titl'
# page_content='e="학사모니터"
#
#
# 							>
# 								학사모니터
# 							<'
# page_content='/a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/monitor/01.jsp"'
# page_content='title="소개"'
# page_content='>
# 													소개'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/monitor/02.jsp"'
# page_content='title="실시일정"'
# page_content='>
# 													실시일정'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/campuslife/monitor/03.jsp"'
# page_content='title="부서별 조치사항"'
# page_content='>
# 													부서별 조치사'
# page_content='항
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>
#
#
#
#
#
# 			<'
# page_content='/ul>
#
#
# 		</li>'
# page_content='<li class="">
#
# 					<a href="/jj/education/career/notice_sta'
# page_content='rt.jsp"
#
#
#
#
# 						title="진로/취업/교육"'
# page_content='>
#
# 				진로/취업/교육
# 			</a>'
# page_content='<ul class="depth02">'
# page_content='<li class="">
#
# 							<a href="/jj/education/career/n'
# page_content='otice_start.jsp"'
# page_content='title="진로개발"
#
#
# 							>
# 								진로개발'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/career/notice_start.jsp"'
# page_content='title="StarT'
# page_content='프로그램"
#
#
# 												>'
# page_content='StarT 프로그램
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/career/risingstar.jsp"'
# page_content='title="라이징스타 프'
# page_content='로그램"
#
#
# 												>'
# page_content='라이징스타 프로그램
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/career/superrookie.jsp"'
# page_content='title="수퍼루키 프'
# page_content='로그램"
#
#
# 												>'
# page_content='수퍼루키 프로그램
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/practice.jsp"'
# page_content='title="현장실습/캡스톤디자인"'
# page_content='>
# 													현장실습/캡스'
# page_content='톤디자인
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/education/recruit/'
# page_content='notice_funprogram.jsp"'
# page_content='title="취업역량개발"
#
#
# 							>'
# page_content='취업역량개발
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/recruit/notice_funprogram.jsp"'
# page_content='title='
# page_content='"진로·취업 프로그램"
#
#
# 												>'
# page_content='진로·취업 프로그램
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"https://www.jj.ac.kr/job/"'
# page_content='target="_blank"'
# page_content='title="대학일자리플러스센터 (새창열림)" rel="noopener noreferre'
# page_content='r"'
# page_content='>
# 													대학일자리플러스센터
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/recruit/recommend_recruitinfo.jsp"'
# page_content='ti'
# page_content='tle="추천채용"
#
#
# 												>'
# page_content='추천채용
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/recruit/recruitinfo.jsp"'
# page_content='title="채용정보"'
# page_content='>
# 													채용정'
# page_content='보
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"https://www.worldjob.or.kr"'
# page_content='target="_blank"'
# page_content='title="해외취업정보 (새창열림)" rel="noopener noreferrer"'
# page_content='>
# 													해외취업정보
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/recruit/jobcommunity.jsp"'
# page_content='title="취업커뮤'
# page_content='니티"
#
#
# 												>'
# page_content='취업커뮤니티
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://www.work.go.kr/jobyoung"'
# page_content='target="_blank"'
# page_content='title="청년일자리정책 (새창열림)" rel="noopener norefer'
# page_content='rer"'
# page_content='>
# 													청년일자리정책
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://www.work.go.kr"'
# page_content='target="_blank"'
# page_content='title="워크넷 (새창열림)" rel="noopener noreferrer"'
# page_content='>
# 													워크넷
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/education/global.j'
# page_content='sp"
#
#
#
#
# 										title="국제'
# page_content='화"
#
#
# 							>
# 								국제화
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/global.jsp"'
# page_content='title="국제교류원"'
# page_content='>
# 													국제교류원'
# page_content='</a>
# 											</li>
#
#
# 								</ul'
# page_content='>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/education/cyber.js'
# page_content='p"
#
#
#
#
# 										title="원격교'
# page_content='육"
#
#
# 							>
# 								원격교육
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/cyber.jsp"'
# page_content='title="사이버캠퍼스"'
# page_content='>
# 													사이버캠퍼스'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/ctl.jsp"'
# page_content='title="교수학습개발센터"'
# page_content='>
# 													교수학습개발센터'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/cde.jsp"'
# page_content='title="원격교육지원센터"'
# page_content='>
# 													원격교육지원센터'
# page_content='</a>
# 											</li>
#
#
# 								<'
# page_content='/ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/education/conedu.j'
# page_content='sp"
#
#
#
#
# 										title="열린'
# page_content='교육"
#
#
# 							>
# 								열린교육
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/conedu.jsp"'
# page_content='title="평생교육원"'
# page_content='>
# 													평생교육원'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/education/midedu.jsp"'
# page_content='title="교육연수원"'
# page_content='>
# 													교육연수원'
# page_content='</a>
# 											</li>
#
#
# 								</ul'
# page_content='>
#
# 						</li>
#
#
#
# 			</ul>
#
#
# 		</li>'
# page_content='<li class="">
#
# 					<a href="/jj/community/notice/gennotice.'
# page_content='jsp"
#
#
#
#
# 						title="커뮤니티"'
# page_content='>
#
# 				커뮤니티
# 			</a>'
# page_content='<ul class="depth02">'
# page_content='<li class="">
#
# 							<a href="/jj/community/notice/g'
# page_content='ennotice.jsp"'
# page_content='title="공지사항"
#
#
# 							>
# 								공지사항'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/notice/gennotice.jsp"'
# page_content='title="공지사항(일반)'
# page_content='"
#
#
# 												>
# 													공지'
# page_content='사항(일반)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/notice/haksanotice.jsp"'
# page_content='title="공지사항(학'
# page_content='사)"
#
#
# 												>'
# page_content='공지사항(학사)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/notice/janghaknotice.jsp"'
# page_content='title="공지사항'
# page_content='(장학)"
#
#
# 												>'
# page_content='공지사항(장학)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/notice/gongmonotice.jsp"'
# page_content='title="공지사항('
# page_content='공모)"
#
#
# 												>'
# page_content='공지사항(공모)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/notice/bidnotice.jsp"'
# page_content='title="공지사항(구매/'
# page_content='입찰)"
#
#
# 												>'
# page_content='공지사항(구매/입찰)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/notice/recruitnotice.jsp"'
# page_content='title="공지사항'
# page_content='(채용)"
#
#
# 												>'
# page_content='공지사항(채용)
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</l'
# page_content='i>'
# page_content='<li class="">
#
# 							<a href="/jj/community/news/eve'
# page_content='nt.jsp"
#
#
#
#
# 										title'
# page_content='="행사/이벤트"
#
#
# 							>
# 								행사/이벤트'
# page_content='</a>
#
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/community/jjboard/'
# page_content='study.jsp"
#
#
#
#
# 										ti'
# page_content='tle="JJ 보드"
#
#
# 							>
# 								JJ 보드'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/jjboard/study.jsp"'
# page_content='title="공모전/스터디"'
# page_content='>
# 													공모전/스터'
# page_content='디
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/jjboard/alba.jsp"'
# page_content='title="모집/아르바이트"'
# page_content='>
# 													모집/아르바'
# page_content='이트
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/jjboard/lost.jsp"'
# page_content='title="분실/습득물"'
# page_content='>
# 													분실/습득물'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/jjboard/oneroom.jsp"'
# page_content='title="자취/하숙/원룸"'
# page_content='>
# 													자취/'
# page_content='하숙/원룸
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/community/qna.jsp"'
# page_content='title="학생문의/'
# page_content='상담"
#
#
# 							>
# 								학생문의/상담
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/qna.jsp"'
# page_content='title="Q&amp;A"'
# page_content='>
# 													Q&amp;A'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/faq.jsp"'
# page_content='title="FAQ"'
# page_content='>
# 													FAQ
# 												</a>'
# page_content='</li>
#
#
# 								</ul>'
# page_content='</li>'
# page_content='<li class="">
#
# 							<a href="/jj/community/proposal'
# page_content='/suggestion.jsp"'
# page_content='title="구성원참여소통"
#
#
# 							>
# 								구성원참'
# page_content='여소통
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/proposal/suggestion.jsp"'
# page_content='title="학사구조'
# page_content='및 정책 제안"
#
#
# 												>'
# page_content='학사구조 및 정책 제안
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/proposal/baro.jsp"'
# page_content='title="바로바로센터(민원 및'
# page_content='불편신고)"
#
#
# 												>'
# page_content='바로바로센터(민원 및 불편신고)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/community/proposal/itbaro.jsp"'
# page_content='title="IT바로바로센터"'
# page_content='>
# 													IT바'
# page_content='로바로센터
# 												</a>
# 											</li>'
# page_content='</ul>
#
# 						</li>'
# page_content='</ul>
#
#
# 		</li>'
# page_content='<li class="">
#
# 					<a href="/jj/smartjj/cloud/portalapp.jsp'
# page_content='"
#
#
#
#
# 						title="스마트 JJ"'
# page_content='>
#
# 				스마트 JJ
# 			</a>'
# page_content='<ul class="depth02">'
# page_content='<li class="">
#
# 							<a href="http://instar.jj.ac.kr'
# page_content='"
#
#
#
#
# 										target="_blank"'
# page_content='title="포털서비스 (새창열림)" rel="noopener norefe'
# page_content='rrer"
#
#
#
#
#
# 							>'
# page_content='포털서비스
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://instar.jj.ac.kr"'
# page_content='target="_blank"'
# page_content='title="학생(inSTAR) (새창열림)" rel="noopener noreferrer"'
# page_content='>
# 													학생(inSTAR)
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://onstar.jj.ac.kr"'
# page_content='target="_blank"'
# page_content='title="학생역량개발(onSTAR) (새창열림)" rel="noopener noreferr'
# page_content='er"'
# page_content='>
# 													학생역량개발(onSTAR)
# 												<'
# page_content='/a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://juis.jj.ac.kr"'
# page_content='target="_blank"'
# page_content='title="교직원(JUIS) (새창열림)" rel="noopener noreferrer"'
# page_content='>
# 													교직원(JUIS)
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://instar.jj.ac.kr/jjpa"'
# page_content='target="_blank"'
# page_content='title="학부모 알리미 (새창열림)" rel="noopener noreferrer'
# page_content='"'
# page_content='>
# 													학부모 알리미
# 												</a>'
# page_content='</li>
#
#
# 								</ul>'
# page_content='</li>'
# page_content='<li class="">
#
# 							<a href="http://jj.webminwon.kr'
# page_content='"
#
#
#
#
# 										target="_blank"'
# page_content='title="증명서 발급 (새창열림)" rel="noopener noref'
# page_content='errer"
#
#
#
#
#
# 							>'
# page_content='증명서 발급
# 							</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://jj.webminwon.kr"'
# page_content='target="_blank"'
# page_content='title="인터넷 증명발급 (새창열림)" rel="noopener noreferrer"'
# page_content='>
# 													인터넷 증명발급
# 												</a>'
# page_content='</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"http://instar.jj.ac.kr"'
# page_content='target="_blank"'
# page_content='title="교육비납입영수증출력 (새창열림)" rel="noopener noreferrer"'
# page_content='>
# 													교육비납입영수증출력
# 												</a>'
# page_content='</li>
#
#
# 								</ul>'
# page_content='</li>'
# page_content='<li class="">
#
# 							<a href="/jj/smartjj/pchelper_i'
# page_content='ntro.jsp"
#
#
#
#
# 										tit'
# page_content='le="IT헬프데스크"
#
#
# 							>
# 								IT헬프데스크'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/pchelper_intro.jsp"'
# page_content='title="PC Helper 서비'
# page_content='스"
#
#
# 												>
# 													P'
# page_content='C Helper 서비스
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/pcclinic.jsp"'
# page_content='title="교내 PC 클리닉"'
# page_content='>
# 													교내 PC 클리닉'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/remote.jsp"'
# page_content='title="원격지원서비스"'
# page_content='>
# 													원격지원서비스'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/pcpractice.jsp"'
# page_content='title="전산 실습실"'
# page_content='>
# 													전산 실습실'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/faq.jsp"'
# page_content='title="자주 묻는 질문"'
# page_content='>
# 													자주 묻는 질문'
# page_content='</a>
# 											</li>
#
#
# 								</u'
# page_content='l>
#
# 						</li>'
# page_content='<li class="">
#
# 							<a href="/jj/smartjj/cloud/port'
# page_content='alapp.jsp"
#
#
#
#
# 										ti'
# page_content='tle="클라우드/모바일"
#
#
# 							>
# 								클라우드/모바일'
# page_content='</a>'
# page_content='<ul class="depth03">'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/cloud/portalapp.jsp"'
# page_content='title="포털 앱(JJ 스마트'
# page_content='캠퍼스)"
#
#
# 												>'
# page_content='포털 앱(JJ 스마트캠퍼스)
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/cloud/attendance.jsp"'
# page_content='title="출결관리"'
# page_content='>
# 													출결관리'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/cloud/mail.jsp"'
# page_content='title="웹메일"'
# page_content='>
# 													웹메일'
# page_content='</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/cloud/office365.jsp"'
# page_content='title="Office 365"'
# page_content='>
# 													Off'
# page_content='ice 365
# 												</a>
# 											</li>'
# page_content='<li class="">
#
#
# 												<a href='
# page_content='"/jj/smartjj/cloud/mobiledownload.jsp"'
# page_content='title="모바일 다운'
# page_content='로드 센터"
#
#
# 												>'
# page_content='모바일 다운로드 센터
# ...
# page_content='j.ac.kr/jj/etc/kimyoungran.jsp"onClick="window.open(this.hre'
# page_content='f, '', 'width=550, height=400, left=200, top=100, toolbar=no'
# page_content=''); return false;"
#                         title="청탁금지법 관련 홍'
# page_content='보영상 및 매뉴얼 새창열림">
#                         <img src="/jj/_res/'
# page_content='img/common/img-banner03.gif" alt="청탁금지법 관련 홍보영상 및 매뉴얼">'
# page_content='</a>
#                 </div>'
# page_content='<div class="item">
#                     <a href="http://www.k'
# page_content='cue.or.kr" target="_blank" title="한국대학교육협의회 새창열림">'
# page_content='<img src="/jj/_res/img/common/img-banner04.gi'
# page_content='f"
#                             alt="한국대학교육협의회 koren council'
# page_content='for university education">
#                     </a>'
# page_content='</div>'
# page_content='<div class="item">
#                     <a href="http://www.a'
# page_content='cademyinfo.go.kr/pubinfo/pubinfo1600/doInit.do?schlId=000017'
# page_content='1" target="_blank"
#                         title="대학알리미 새창열림'
# page_content='">
#                         <img src="/jj/_res/img/common/img'
# page_content='-banner05.gif" alt="대학알리미 higher education in korea">'
# page_content='</a>
#                 </div>'
# page_content='<div class="item">
#                     <a href="http://www.m'
# page_content='oe.go.kr/onedu.do" title="온라인소통광장 온-교육 새창열림" target="_blank"'
# page_content='>
#                         <img src="/jj/_res/img/common/img-'
# page_content='banner06.gif" alt="교육에 관한 모든 이야기 온라인소통광장 온-교육">'
# page_content='</a>
#                 </div>'
# page_content='<div class="item">
#                     <a href="/jj/_res/img'
# page_content='/common/img-banner-poster.jpg" title="개인정보 처리 업무위탁 새창열림" tar'
# page_content='get="_blank">
#                         <img src="/jj/_res/img'
# page_content='/common/img-banner07.gif" alt="개인정보 처리 업무위탁 홍보 안내">'
# page_content='</a>
#                 </div>'
# page_content='<div class="item">
#                     <a href="/jj/_res/img'
# page_content='/common/img-banner-poster02.jpg" title="영상정보처리기기 설치·운영 안내 새창'
# page_content='열림" target="_blank">
#                         <img src="/jj/_'
# page_content='res/img/common/img-banner08.gif" alt="영상정보처리기기 설치·운영 안내">'
# page_content='</a>
#                 </div>'
# page_content='<div class="item">
#                     <a href="/jj/_res/img'
# page_content='/common/img-banner-poster05.jpg" title="개인정보 유출사고 위험진단 새창열림"'
# page_content='target="_blank">
#                         <img src="/jj/_res'
# page_content='/img/common/img-banner12.gif" alt="개인정보 유출사고 위험진단 안내">'
# page_content='</a>
#                 </div>
#             </div'
# page_content='>'
# page_content='<div class="control-wrap">
#                 <a class="prev" h'
# page_content='ref="#">'
# page_content='<span class="hide">prev</span></a>
#                 <a class='
# page_content='"next" href="#">'
# page_content='<span class="hide">next</span></a>
#             </div>'
# page_content='</div>
#     </div>
# </div>
# </div>
# 		</div>
# 	</div>'
# page_content='<footer>'
# page_content='<div class="top-footer-wrap">
# <div class="outer">'
# page_content='<div class="top-footer-box">'
# page_content='<ul class="lnk-ul">'
# page_content='<li class="row02">'
# page_content='<p>기관/부서</p>'
# page_content='<ul class="lnk-ul02">'
# page_content='<li><a href="https://icee.jj.ac.kr" target="_blank" title="공'
# page_content='학교육혁신센터 새창열림">공학교육혁신센터</a></li>'
# page_content='<li><a href="https://ctl.jj.ac.kr" target="_blank" title="교수'
# page_content='학습개발센터 새창열림">교수학습개발센터</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/tedu" target="_blank" titl'
# page_content='e="교육연수원 새창열림">교육연수원</a></li>'
# page_content='<li><a href="https://global.jj.ac.kr" target="_blank" title='
# page_content='"국제교류원 새창열림">국제교류원 </a></li>'
# page_content='<li><a href="https://www.gpa.ac.kr" target="_blank" title="국'
# page_content='제영재아카데미 새창열림">국제영재아카데미</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/aber/" target="_blank" tit'
# page_content='le="농생명융합기술원 새창열림">농생명융합기술원 </a></li>'
# page_content='<li><a href="https://lib.jj.ac.kr" target="_blank" title="도서'
# page_content='관 새창열림">도서관</a></li>
#                     <!--'
# page_content='<li><a href="http://jjchurch.net" target="_blank" title="대학교'
# page_content='회 새창열림">대학교회</a></li> -->'
# page_content='<li><a href="https://www.jj.ac.kr/job" target="_blank" title'
# page_content='="대학일자리플러스센터 새창열림">대학일자리플러스센터</a></li>'
# page_content='<li><a href="https://jj.ac.kr/jjnews" target="_blank" title='
# page_content='"미디어센터 새창열림">미디어센터</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/privatesecurity" target="_'
# page_content='blank" title="민간경비교육센터 새창열림">민간경비교육센터</a></li>'
# page_content='<li><a href="https://museum.jj.ac.kr" target="_blank" title='
# page_content='"박물관 새창열림">박물관</a></li>'
# page_content='<li><a href="https://fund.jj.ac.kr" target="_blank" title="발'
# page_content='전기금홈페이지 새창열림">발전기금홈페이지</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/volunteer" target="_blank"'
# page_content='title="사회봉사센터 새창열림">사회봉사센터</a></li>'
# page_content='<li><a href="http://cde.jj.ac.kr" target="_blank" title="원격교'
# page_content='육지원센터 새창열림">원격교육지원센터</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/humanrights" target="_blan'
# page_content='k" title="인권센터 새창열림">인권센터</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/ctc" target="_blank" title'
# page_content='="장애학생지원센터 새창열림">장애학생지원센터</a></li>'
# page_content='<li><a href="https://its.jj.ac.kr/" target="_blank" title="정'
# page_content='보통신원 새창열림">정보통신원</a></li>'
# page_content='<li><a href="https://ric.jj.ac.kr" target="_blank" title="지역'
# page_content='혁신공유협업센터 새창열림">지역혁신공유협업센터</a></li>'
# page_content='<li><a href="/jj/campuslife/defense/01.jsp" title="직장예비군연대 바'
# page_content='로가기">직장예비군연대</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/happyjcc" target="_blank"'
# page_content='title="카운슬링센터 새창열림">카운슬링센터</a></li>'
# page_content='<li><a href="https://conedu.jj.ac.kr" target="_blank" title='
# page_content='"평생교육원 새창열림">평생교육원</a></li>'
# page_content='<li><a href="https://startower.jj.ac.kr" target="_blank" tit'
# page_content='le="학생생활관(기숙사) 새창열림">학생생활관(기숙사)</a></li>'
# page_content='<li><a href="https://ssc.jj.ac.kr" target="_blank" title="학생'
# page_content='서비스센터 새창열림">학생서비스센터</a></li>
#                 </ul>'
# page_content='</li>'
# page_content='<li class="row02">'
# page_content='<p>대학/대학원</p>'
# page_content='<ul class="lnk-ul02">'
# page_content='<li><a href="https://www.jj.ac.kr/humanities" target="_blank'
# page_content='" title="인문콘텐츠대학 새창열림">인문콘텐츠대학</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/graduate" target="_blank"'
# page_content='title="일반대학원 새창열림">일반대학원</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/social" target="_blank" ti'
# page_content='tle="사회과학대학 새창열림">사회과학대학</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/graduate" target="_blank"'
# page_content='title="경영행정대학원 새창열림">경영행정대학원</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/biz" target="_blank" title'
# page_content='="경영대학 새창열림">경영대학</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/graduate" target="_blank"'
# page_content='title="교육대학원 새창열림">교육대학원</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/med" target="_blank" title'
# page_content='="의과학대학 새창열림">의과학대학 </a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/graduate" target="_blank"'
# page_content='title="문화산업대학원 새창열림">문화산업대학원</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/engin" target="_blank" tit'
# page_content='le="공과대학 새창열림">공과대학</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/graduate" target="_blank"'
# page_content='title="보건복지대학원 새창열림">보건복지대학원</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/sw" target="_blank" title='
# page_content='"소프트웨어융합대학 새창열림">소프트웨어융합대학</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/graduate" target="_blank"'
# page_content='title="선교신학대학원 새창열림">선교신학대학원</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/c3" target="_blank" title='
# page_content='"문화융합대학 새창열림">문화융합대학</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/graduate" target="_blank"'
# page_content='title="상담심리대학원 새창열림">상담심리대학원</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/ct" target="_blank" title='
# page_content='"문화관광대학 새창열림">문화관광대학</a></li>'
# page_content='<li></li>'
# page_content='<li><a href="https://www.jj.ac.kr/edu" target="_blank" title'
# page_content='="사범대학 새창열림">사범대학</a></li>'
# page_content='<li></li>'
# page_content='<li><a href="https://www.jj.ac.kr/future" target="_blank" ti'
# page_content='tle="미래융합대학 새창열림">미래융합대학</a></li>'
# page_content='<li></li>'
# page_content='<li><a href="https://www.jj.ac.kr/superstar" target="_blank"'
# page_content='title="수퍼스타칼리지 새창열림">수퍼스타칼리지</a></li>
#                 </ul>'
# page_content='</li>'
# page_content='<li>'
# page_content='<p>산학협력/연구</p>'
# page_content='<ul class="lnk-ul02">'
# page_content='<li><a href="https://www.jj.ac.kr/sanhak"target="_blank"  ti'
# page_content='tle="산학협력단 새창열림">산학협력단</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/superstarkids/" target="_b'
# page_content='lank" title="수퍼스타어린이집 새창열림">수퍼스타어린이집</a></li>'
# page_content='<li style="white-space:nowrap;"><a href="http://www.jjwansan'
# page_content='.or.kr/" target="_blank" title="어린이급식관리지원센터 새창열림">어린이급식관리지원센'
# page_content='터</a></li>'
# page_content='<li><a href="https://startup.jj.ac.kr" target="_blank" title'
# page_content='="창업지원단 새창열림">창업지원단</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/practice" target="_blank"'
# page_content='title="현장실습지원센터 새창열림">현장실습지원센터</a></li>'
# page_content='<!--'
# page_content='<li><a href="https://linc.jj.ac.kr" target="_blank" title="L'
# page_content='INC+사업단 새창열림">LINC3.0사업단</a></li>-->
#                 </ul>'
# page_content='</li>'
# page_content='<li>'
# page_content='<p>서비스/프로그램</p>'
# page_content='<ul class="lnk-ul02">'
# page_content='<li><a href="https://abeek.jj.ac.kr" target="_blank" title="'
# page_content='공학인증ABEEK 새창열림">공학인증ABEEK</a></li>'
# page_content='<li><a href="https://recruit.jj.ac.kr" target="_blank" title'
# page_content='="교원/직원 채용 새창열림">교원/직원 채용</a></li>'
# page_content='<li><a href="https://cyber.jj.ac.kr" target="_blank" title="'
# page_content='사이버캠퍼스 새창열림">사이버캠퍼스</a></li>'
# page_content='<li><a href="http://jj.webminwon.kr" target="_blank" title="'
# page_content='증명발급 새창열림">증명발급</a></li>'
# page_content='<li><a href="https://instar.jj.ac.kr" target="_blank" title='
# page_content='"inSTAR 새창열림">inSTAR</a></li>'
# page_content='<li><a href="https://juis.jj.ac.kr" target="_blank" title="J'
# page_content='UIS 새창열림">JUIS</a></li>'
# page_content='<li><a href="https://onstar.jj.ac.kr" target="_blank" title='
# page_content='"onSTAR 새창열림">onSTAR</a></li>
#                 </ul>'
# page_content='</li>'
# page_content='<li>'
# page_content='<p>자치기구/유관기관</p>'
# page_content='<ul class="lnk-ul02">'
# page_content='<li><a href="https://faculty.jj.ac.kr" target="_blank" title'
# page_content='="교수회 새창열림">교수회</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/p_union" target="_blank" t'
# page_content='itle="교수노동조합 새창열림">교수노동조합</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/pfm" target="_blank" title'
# page_content='="교수선교회 새창열림">교수선교회</a></li>'
# page_content='<li><a href="https://www.jj.ac.kr/senate" target="_blank" ti'
# page_content='tle="대학평의원회 새창열림">대학평의원회</a></li>'
# page_content='<li><a href="https://www.evermiracle.com" target="_blank" ti'
# page_content='tle="에버미라클 새창열림">에버미라클</a></li>'
# page_content='<li><a href="https://nojo.jj.ac.kr" target="_blank" title="노'
# page_content='동조합 새창열림">직원노동조합</a></li>'
# page_content='<li><a href="https://www.facebook.com/jjunivch" target="_bla'
# page_content='nk" title="총학생회 새창열림">총학생회</a></li>
#                     <!--'
# page_content='<li><a href="http://www.visioncyber.co.kr" target="_blank" t'
# page_content='itle="비전원격평생교육원 새창열림">비전원격평생교육원</a></li>-->'
# page_content='</ul>
#             </li>
#         </ul>
#     </div>
# </div>
# </di'
# page_content='v>'
# page_content='<div class="bottom-footer-wrap">
# <div class="outer">'
# page_content='<div class="bottom-footer-box">'
# page_content='<div class="top-footer-inner">'
# page_content='<div class="footer-logo-box">
#                 <img src="/jj/'
# page_content='_res/img/common/img-footer-logo.png" alt="Jeonju University'
# page_content='The Place for superstars" />
#             </div>'
# page_content='<div class="etc-lnk-box">'
# page_content='<ul>'
# page_content='<li><a href="https://www.academyinfo.go.kr/popup/pubinfo1690'
# page_content='/list.do?schlId=0000171" target="_blank">공시정보</a></li>'
# page_content='<li class="privacy"><a href="/jj/personal_information.jsp" t'
# page_content='arget="_blank" title="개인정보처리방침 새창열림" rel="noopener noreferre'
# page_content='r">개인정보처리방침</a></li>'
# page_content='<li><a href="/jj/introduction/budget.jsp" target="_blank" ti'
# page_content='tle="예결산공고 새창열림" rel="noopener noreferrer">예결산공고</a></li>'
# page_content='<li><a href="/jj/jjuniv/self-evaluation.jsp" target="_blank"'
# page_content='title="자체평가결과보고서 새창열림" rel="noopener noreferrer">자체평가결과보고서<'
# page_content='/a></li>'
# page_content='<li><a href="/jj/jjuniv/public-information.jsp" target="_bla'
# page_content='nk" title="정보공개제도 새창열림" rel="noopener noreferrer">정보공개제도</a>'
# page_content='</li>'
# page_content='<li><a href="/jj/jjuniv/illegal-solicitation.jsp" target="_b'
# page_content='lank" title="청탁금지법 관련 공지 새창열림" rel="noopener noreferrer">청탁금'
# page_content='지법 관련 공지</a></li>'
# page_content='<li><a href="/jj/jjuniv/cctv_guide.jsp" target="_blank" titl'
# page_content='e="영상정보처리기기운영관리방침 새창열림" rel="noopener noreferrer">영상정보처리기기운영'
# page_content='&middot; 관리방침</a></li>'
# page_content='<li><a href="/jj/jjuniv/call_guide.jsp" target="_blank" titl'
# page_content='e="행정전화 녹취시스템 운영·관리 방침 새창열림" rel="noopener noreferrer">행정전화'
# page_content='녹취시스템 운영·관리 방침</a></li>
#                 </ul>
#             </'
# page_content='div>
#         </div>'
# page_content='<div class="bottom-footer-inner">'
# page_content='<div class="footer-info-box">'
# page_content='<p>(55069) 전북특별자치도 전주시 완산구 천잠로 303 전주대학교</p>'
# page_content='<ul>'
# page_content='<li><a href="tel:1577-7177" title="전화걸기">TEL : +82-1577-7177'
# page_content='</a></li>'
# page_content='<li>FAX : +82-63-220-2464</li>'
# page_content='<li><a href="mailto:webmaster@jj.ac.kr" title="메일보내기">E-MAIL'
# page_content=': webmaster@jj.ac.kr</a></li>
#                 </ul>'
# page_content='<p class="copyright">Copyrights (C)2020 Jeonju University. A'
# page_content='ll Rights Reserved.</p>
#             </div>'
# page_content='<div class="footer-sns-box">'
# page_content='<ul>'
# page_content='<li class="facebook">
#                         <a href="http:'
# page_content='//www.facebook.com/discoveryjjss" target="_blank" title="fac'
# page_content='ebook 새창열림" rel="noopener noreferrer">facebook</a>'
# page_content='</li>'
# page_content='<li class="youtube">
#                         <a href="https:'
# page_content='//www.youtube.com/user/todwn" target="_blank" title="youtube'
# page_content='새창열림" rel="noopener noreferrer">youtube</a>'
# page_content='</li>'
# page_content='<li class="instagram"><a href="https://www.instagram.com/jju'
# page_content='niv/?hl=ko" target="_blank" title="instagram 새창열림" rel="noop'
# page_content='ener noreferrer">instagram</a></li>'
# page_content='<li class="blog"><a href="http://blog.naver.com/discoveryj"'
# page_content='target="_blank" title="blog 새창열림" rel="noopener noreferrer">'
# page_content='blog</a></li>
#                 </ul>
#             </div>'
# page_content='<div class="footer-mark-box">
#                 <a href="https'
# page_content='://startup.jj.ac.kr" target="_blank" title="창업선도대학 새창열림" rel'
# page_content='="noopener noreferrer"><img src="/jj/_res/img/common/img-mar'
# page_content='k01.png" alt="창업선도대학"/></a>
#                 <a title="LINC 새'
# page_content='창열림" rel="noopener noreferrer"><img src="/jj/_res/img/common'
# page_content='/img-mark03.png" alt="LINC3.0"/></a>
# 				<!--href="https://l'
# page_content='inc.jj.ac.kr" target="_blank"-->
#             </div>'
# page_content='</div>
#     </div>
# </div>
# </div>
# 	</footer>
# </div>
# <noscript>'
# page_content='<p>이 사이트는 자바스크립트를 지원하지 않으면 정상적으로 보이지 않을수 있습니다.</p></noscript'
# page_content='>
# </body>
# </html>'
