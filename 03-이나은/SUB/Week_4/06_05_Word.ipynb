# %% [markdown]
# ## MSWord Loader

# %%
pip install -qU docx2txt langchain_community
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import Docx2txtLoader

loader = Docx2txtLoader('/content/논문작성양식.docx')

docs = loader.load()

print(len(docs))
# Out:
# 1

# %%
print(docs[0].page_content)
# Out:
# 논문 작성 양식 안내
#
#
#
# ✽모든 논문은 국문과 중문으로 각각 작성한다.
#
# ✽해당 양식에 어긋나는 논문은 게재 불가
#
#
#
# ☞ 분량: Word에서 한글 작성 기준 참고문헌 포함 A4 15매 이상
#
# (표지, 초록, 목차, 부록 불포함)
#
#
#
# ☞ 격식: (MS Word) 글자크기 11, 돋움(중문 SimSun), 줄간격 1.15,
#
# 페이지여백 상하 3.3cm, 좌우 3.5cm (상단 페이지레이아웃 탭 – 여백 – 사용자지정)
#
#   장절 기호는 1.→1.1→1.1.1
#
#         예시) 1. 서론
#
#               2. 한중 문화교류의 역사
#
#                  2.1. 한중 수교 이전의 문화교류
#
#                  2.2. 한중 수교 이후의 문화교류
#
#                  …….
#
#               4. 결론
#
#
#
# ☞ 본문 작성: 단락 들여쓰기는 한글/중문 각각 원고지 작성법을 따른다.
#
#               (한글 원고지 1칸/ 중문 원고지 2칸)
#
# 단락 바꾸기 줄 비움 없이 들여쓰기.
#
#
#
# ☞ 그림, 표 삽입: <그림1>제목, <표1> 제목… (표/그림 우측 하단에 출처 명기)
#
#
#
# ☞ 참고문헌 및 주석 표기법:
#
# 1) 참고문헌 정렬기준:
#
# - 한글자모, 알파벳 순 정렬 (한글문헌, 동양문헌, 서양문헌 순으로 정리)
#
# - 동일저자의 여러 자료의 경우 년도 순으로 정렬
#
# 2) 표기법
#
# ①참고문헌:
#
# - 저자, 『도서명』(「논문명」), 출판사, 출판연도(국문, 영문 동일),
#
# - 한글문헌 1)서적 2)학술지·보고서 3)언론보도 4)인터넷자료 → 중국문헌 (한글문헌과 동일한 순서로 서적, 학술지, 언론보도 분류 기재) → 서양문헌 순으로 정리 (위와 동일)
#
# ②주석:
#
# ...
