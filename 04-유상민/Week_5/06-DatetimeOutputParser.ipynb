# %%
import os

os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGCHAIN_API_KEY"] = ""
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"] = "03-06"

# %%
# !pip install -qU langchain_openai

# %%
from langchain.output_parsers import datetime
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

# %%
output_parser = datetime.DatetimeOutputParser()
output_parser.format = '%Y-%m-%d %H %M'

# %%
template = """Answer the user question:

    #Format instructions:
    {format_instructions}
    #Question:
    {question}

    #Answer: """

prompt = PromptTemplate.from_template(
    template,
    partial_variables={
        "format_instructions": output_parser.get_format_instructions()
        },
)

# %%
output_parser.get_format_instructions()
# Out:
# "Write a datetime string that matches the following pattern: '%Y-%m-%d %H %M '.\n\nExamples: 1462-12-10 17 01 , 1896-05-23 01 39 , 1463-04-16 23 51 \n\nReturn ONLY this string, no other words!"

# %%
llm = ChatOpenAI(temperature=0)

chain = prompt | llm | output_parser

# %%
response = chain.invoke('today')

response
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/langchain/output_parsers/datetime.py in parse(self, response)
#      49         try:
# ---> 50             return datetime.strptime(response.strip(), self.format)
#      51         except ValueError as e:
#
# /usr/lib/python3.11/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     format string."""
# --> 567     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     568     tzname, gmtoff = tt[-2:]
#
# /usr/lib/python3.11/_strptime.py in _strptime(data_string, format)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#
# ValueError: time data '2022-01-06 15 45' does not match format '%Y-%m-%d %H %M '
#
# ...
