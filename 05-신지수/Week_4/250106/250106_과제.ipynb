# %% [markdown]
# ### ###과제

# %%
pip install -qU langchain_community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 29.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 4.1 MB/s eta 0:00:00

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path = "/content/data/BostonHousing.csv")

docs = loader.load()

print(len(docs))
print(docs[0].metadata)
print(docs[0].page_content)
# Out:
# 506
# {'source': '/content/data/BostonHousing.csv', 'row': 0}
# crim: 0.00632
# zn: 18
# indus: 2.31
# chas: 0
# nox: 0.538
# rm: 6.575
# age: 65.2
# dis: 4.09
# rad: 1
# tax: 296
# ptratio: 15.3
# b: 396.9
# lstat: 4.98
# medv: 24

# %%
loader = CSVLoader(
    file_path = '/content/data/BostonHousing.csv',
    csv_args = {
        "delimiter":".",    # 구분자
        "quotechar":'"',    # 인용 부호 문자
        "filedness": [
            "crim"   # 도시 당 인당 범죄율
            "zn"     # 25,000 평방피트 이상의 주고용 토지 비율
            "indus"  # 도시 당 비소매 사업지 비율
            "chas"   # 찰스 강 더미 변수(강 가장자리인 경우 1, 그렇지않으면 0)
            "nox"    # 질소산화물 농도 (1000만 분의 1 단위)
            "rm"     # 주거 당 평균 방 수
            "age"    # 1940년 이전에 건설된 소유주 거주 단위 비율
            "dis"    # 보스턴 고용 센터까지의 가중 거리
            "rad"    # 방사형 고속도로 접근성 지수
            "tax"    # 10,000달러당 부동산 세율
            "ptratio"# 도시 당 학생 대 교사 비율
            "b"      # (Bk - 0.63)^2, 여기서 Bk는 도시 당 흑인 비율
            "lstat"  # 인구의 하위 계층 비율 %
            "medv"   # 소유주 거주 주택의 중간 가치 (1,000달러 단위)
        ]
    }
)

# %%
print(docs[1].metadata)
print(docs[0].page_content)
# Out:
# {'source': '/content/data/BostonHousing.csv', 'row': 1}
# crim: 0.00632
# zn: 18
# indus: 2.31
# chas: 0
# nox: 0.538
# rm: 6.575
# age: 65.2
# dis: 4.09
# rad: 1
# tax: 296
# ptratio: 15.3
# b: 396.9
# lstat: 4.98
# medv: 24

# %%
row = docs[1].page_content.split('\n')
row_str = '<row>'
for element in row:
  splitted_element = element.split(':')
  value = splitted_element[-1]
  col = ":".join(splitted_element[:-1])
  row_str += f'<{col}>{value.strip()}</{col}>'
row_str += '</row>'

print(row_str)
# Out:
# <row><crim>0.02731</crim><zn>0</zn><indus>7.07</indus><chas>0</chas><nox>0.469</nox><rm>6.421</rm><age>78.9</age><dis>4.9671</dis><rad>2</rad><tax>242</tax><ptratio>17.8</ptratio><b>396.9</b><lstat>9.14</lstat><medv>21.6</medv></row>

# %%
pip install -qU unstructured
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 21.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 48.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 8.5 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders.csv_loader import UnstructuredCSVLoader

loader = UnstructuredCSVLoader(file_path = '/content/data/BostonHousing.csv', mode = "elements")
docs = loader.load()

# 처음 10개 문서만 선택
docs = docs[:10]

# for doc in docs:
    # print(doc.metadata["text_as_html"][:100], "\n")
# Out:
# <table><tr><td>crim</td><td>zn</td><td>indus</td><td>chas</td><td>nox</td><td>rm</td><td>age</td><td

# %%
len(docs)
# Out:
# 1
