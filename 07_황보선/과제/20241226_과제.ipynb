# %% [markdown]
# ## partial variable이 2개 이상일때 관찰.

# %%
import os

os.environ['OPENAI_API_KEY']='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'

# %%
pip install -q langchain_teddynote langchain_openai langchain_core
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.7/34.7 MB 48.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.3/454.3 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 67.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 8.2 MB/s eta 0:00:00
# ...

# %%
from langchain_teddynote.messages import stream_response # 스트리밍 출력
from langchain_core.prompts import PromptTemplate

# %%
pip install -q openai

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model_name='gpt-3.5-turbo',
    max_tokens=2048,
    temperature=0.1,
)

# %%
template = '{x}와 {y}는 {z}입니다.'

prompt = PromptTemplate(
    template=template,
    input_variables=['x'],  # 나중에 입력받을 변수
    partial_variables={     # 미리 정의할 변수
        'y': 'Python',
        'z': '프로그래밍 언어',
    }
)

print(prompt.format(x='Java'))
# Out:
# Java와 Python는 프로그래밍 언어입니다.

# %%
from datetime import datetime

datetime.now().strftime('%B %d')
# Out:
# 'December 26'

# %%
def get_today():
    return datetime.now().strftime('%B %d')

# %%
template = '오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명인 {n}명을 나열해주세요. 생년월일을 표기해주세요.'

prompt = PromptTemplate.from_template(template)
prompt
# Out:
# PromptTemplate(input_variables=['n', 'today'], input_types={}, partial_variables={}, template='오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명인 {n}명을 나열해주세요. 생년월일을 표기해주세요.')

# %%
# prompt 생성
prompt = promtpt.format(today=get_today(), n=2)
prompt
# Out:
# '오늘의 날짜는 December 26 입니다. 오늘이 생일인 유명일 2명을 나열해주세요. 생년월일을 표기해주세요.'

# %%
prompt = PromptTemplate.from_template('오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명인 {n}명을 나열해주세요. 생년월일을 표기해주세요.')

model = ChatOpenAI()

chain = prompt | model

# %%
input = {'today':get_today()}
input
# Out:
# {'today': 'December 26'}

# %%
# template 정의
template = '오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명일 {n}명을 나열해주세요. 생년월일을 표기해주세요.'

prompt = PromptTemplate(
    template=template,
    input_variables=['n'],
    partial_variables={
        'today': get_today(), # dictionary 형태로 partial_variables를 전달
    }
)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['n', 'today'], input_types={}, partial_variables={}, template='오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명인 {n}명을 나열해주세요. 생년월일을 표기해주세요.')

# %%
prompt.format(today=get_today(), n=8)
# Out:
# '오늘의 날짜는 December 26 입니다. 오늘이 생일인 유명인 8명을 나열해주세요. 생년월일을 표기해주세요.'

# %%
chain = prompt | model

# %%
chain.invoke({'today':get_today(), 'n':8}).content
# Out:
# '1. 미란다 코스그로브 (Miranda Cosgrove) - 1993년 12월 26일\n2. 리드 리처 (Reed Richards) - 1961년 12월 26일\n3. 레슬리 과 (Leslie Grossman) - 1971년 12월 26일\n4. 제이크 플로이드 (Jake Lloyd) - 1989년 12월 26일\n5. 헬게 슈나이더 (Helge Schneider) - 1955년 12월 26일\n6. 존 월코트 (John Walcott) - 1957년 12월 26일\n7. 릴 웨인 (Lil Wayne) - 1982년 12월 26일\n8. 루이스 햄린 (Lewis Hamlin) - 1945년 12월 26일'
