# %%
from langchain_text_splitters import (
    Language,
    RecursiveCharacterTextSplitter,
)

# %%
PYTHON_CODE = '''
# 오늘 날짜 12월26일이 생일인 유명인 8명을 나열해주세요. 생년월일을 표기해주세요.
import os
from langchain_teddynote.messages import stream_response # 스트리밍 출력
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from datetime import datetime

os.environ['OPENAI_API_KEY']='path/to/your/openai/api/key'

model = ChatOpenAI(
    model_name='gpt-4',
    max_tokens=2048,
    temperature=0.1,
)
print(datetime.now().strftime('%B %d'))

def get_today():
    return datetime.now().strftime('%B %d')

# template 정의
template = '오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명일 {n}명을 나열해주세요. 생년월일을 표기해주세요.'

prompt = PromptTemplate(
    template=template,
    input_variables=['n'],
    partial_variables={
        'today': get_today(), # dictionary 형태로 partial_variables를 전달
    }
)

prompt.format(today=get_today(), n=8)

chain = prompt | model

print(chain.invoke({'today':get_today(), 'n':8}).content)
'''

python_splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON, chunk_size=50, chunk_overlap=0
)

# %%
python_docs = python_splitter.create_documents([PYTHON_CODE])
python_docs
# Out:
# [Document(metadata={}, page_content='# 오늘 날짜 12월26일이 생일인 유명인 8명을 나열해주세요. 생년월일을 표기해주세요.'),
#  Document(metadata={}, page_content='import os'),
#  Document(metadata={}, page_content='from langchain_teddynote.messages import'),
#  Document(metadata={}, page_content='stream_response # 스트리밍 출력'),
#  Document(metadata={}, page_content='from langchain_core.prompts import PromptTemplate'),
#  Document(metadata={}, page_content='from langchain_openai import ChatOpenAI'),
#  Document(metadata={}, page_content='from datetime import datetime'),
#  Document(metadata={}, page_content="os.environ['OPENAI_API_KEY']='path/to/your/openai"),
#  Document(metadata={}, page_content="/api/key'"),
#  Document(metadata={}, page_content="model = ChatOpenAI(\n    model_name='gpt-4',"),
#  Document(metadata={}, page_content='max_tokens=2048,\n    temperature=0.1,\n)'),
#  Document(metadata={}, page_content="print(datetime.now().strftime('%B %d'))"),
#  Document(metadata={}, page_content='def get_today():'),
#  Document(metadata={}, page_content="return datetime.now().strftime('%B %d')"),
#  Document(metadata={}, page_content='# template 정의'),
#  Document(metadata={}, page_content="template = '오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명일"),
#  Document(metadata={}, page_content="{n}명을 나열해주세요. 생년월일을 표기해주세요.'"),
#  Document(metadata={}, page_content='prompt = PromptTemplate(\n    template=template,'),
#  Document(metadata={}, page_content="input_variables=['n'],"),
#  Document(metadata={}, page_content='partial_variables={'),
#  Document(metadata={}, page_content="'today': get_today(), # dictionary 형태로"),
#  Document(metadata={}, page_content='partial_variables를 전달'),
#  Document(metadata={}, page_content='}\n)'),
#  Document(metadata={}, page_content='prompt.format(today=get_today(), n=8)'),
#  Document(metadata={}, page_content='chain = prompt | model'),
#  Document(metadata={}, page_content="print(chain.invoke({'today':get_today(),"),
#  Document(metadata={}, page_content="'n':8}).content)")]

# %%
for doc in python_docs:
    print(doc.page_content)
    print("------------------")
# Out:
# # 오늘 날짜 12월26일이 생일인 유명인 8명을 나열해주세요. 생년월일을 표기해주세요.
# ------------------
# import os
# ------------------
# from langchain_teddynote.messages import
# ------------------
# stream_response # 스트리밍 출력
# ------------------
# from langchain_core.prompts import PromptTemplate
# ------------------
# from langchain_openai import ChatOpenAI
# ------------------
# from datetime import datetime
# ------------------
# os.environ['OPENAI_API_KEY']='path/to/your/openai
# ------------------
# /api/key'
# ------------------
# model = ChatOpenAI(
#     model_name='gpt-4',
# ------------------
# max_tokens=2048,
#     temperature=0.1,
# )
# ------------------
# print(datetime.now().strftime('%B %d'))
# ------------------
# def get_today():
# ------------------
# return datetime.now().strftime('%B %d')
# ------------------
# # template 정의
# ------------------
# template = '오늘의 날짜는 {today} 입니다. 오늘이 생일인 유명일
# ------------------
# {n}명을 나열해주세요. 생년월일을 표기해주세요.'
# ------------------
# prompt = PromptTemplate(
#     template=template,
# ------------------
# input_variables=['n'],
# ------------------
# partial_variables={
# ------------------
# 'today': get_today(), # dictionary 형태로
# ------------------
# partial_variables를 전달
# ------------------
# }
# )
# ------------------
# prompt.format(today=get_today(), n=8)
# ------------------
# chain = prompt | model
# ------------------
# print(chain.invoke({'today':get_today(),
# ------------------
# 'n':8}).content)
# ------------------
