# %%
html_string = """
<!DOCTYPE html>
  <html lang='en'>
  <head>
    <meta charset='UTF-8'>
    <meta name='viewport' content='width=device-width, initial-scale=1.0'>
    <title>Fancy Example HTML Page</title>
  </head>
  <body>
    <h1>Main Title</h1>
    <p>This is an introductory paragraph with some basic content.</p>

    <h2>Section 1: Introduction</h2>
    <p>This section introduces the topic. Below is a list:</p>
    <ul>
      <li>First item</li>
      <li>Second item</li>
      <li>Third item with <strong>bold text</strong> and <a href='#'>a link</a></li>
    </ul>

    <h3>Subsection 1.1: Details</h3>
    <p>This subsection provides additional details. Here's a table:</p>
    <table border='1'>
      <thead>
        <tr>
          <th>Header 1</th>
          <th>Header 2</th>
          <th>Header 3</th>
        </tr>
      </thead>
      <tbody>
        <tr>
          <td>Row 1, Cell 1</td>
          <td>Row 1, Cell 2</td>
          <td>Row 1, Cell 3</td>
        </tr>
        <tr>
          <td>Row 2, Cell 1</td>
          <td>Row 2, Cell 2</td>
          <td>Row 2, Cell 3</td>
        </tr>
      </tbody>
    </table>

    <h2>Section 2: Media Content</h2>
    <p>This section contains an image and a video:</p>
      <img src='example_image_link.mp4' alt='Example Image'>
      <video controls width='250' src='example_video_link.mp4' type='video/mp4'>
      Your browser does not support the video tag.
    </video>

    <h2>Section 3: Code Example</h2>
    <p>This section contains a code block:</p>
    <pre><code data-lang="html">
    &lt;div&gt;
      &lt;p&gt;This is a paragraph inside a div.&lt;/p&gt;
    &lt;/div&gt;
    </code></pre>

    <h2>Conclusion</h2>
    <p>This is the conclusion of the document.</p>
  </body>
  </html>
"""

# %%
header_to_split_on = [
    ('h1', 'Header_1', # 분할할 헤더 태그와 해당 헤더의 이름을 지정합니다
     'h2', 'Header_2',
     'h3', 'Header_3')
]

# %%
pip install -qU langchain-text-splitters

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

# 지정된 헤더를 기준으로 html 텍스트를 분할하는 htmlheadertextsplitter 객체를 생성합니다
html_splitter = HTMLHeaderTextSplitter(header_to_split_on=header_to_split_on)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b2f51618ffeb> in <cell line: 4>()
#       2
#       3 # 지정된 헤더를 기준으로 html 텍스트를 분할하는 htmlheadertextsplitter 객체를 생성합니다
# ----> 4 html_splitter = HTMLHeaderTextSplitter(header_to_split_on=header_to_split_on)
#
# TypeError: HTMLHeaderTextSplitter.__init__() got an unexpected keyword argument 'header_to_split_on'

# %%
html_header_splits = html_splitter.split_text(html_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4501004632f4> in <cell line: 1>()
# ----> 1 html_header_splits = html_splitter.split_text(html_string)
#
# NameError: name 'html_splitter' is not defined

# %%
for header in html_header_splits:
    print(f'{header.page_content}')
    print(f'{header.metadata}', end='\n=================\n')

# %% [markdown]
# ## 2. WebURL 연결

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

url = 'http://plato.stanford.edu/entries/goedel/' #  분할할 텍스트의 url을 지정

headers_to_split_on = [ # 분할할 html 헤더 태그와 해당 헤더의 이름을 지정합니다
    ('h1', 'Header 1'),
    ('h2', 'Header 2'),
    ('h3', 'Header 3'),
    ('h4', 'Header 4'),
]

# html 헤더를 기준으로 텍스트를 분할하는 htmlheadertextsplitter 객체를 생성
html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

# url에서 텍스트를 가져와 html 헤더를 기준으로 분할
html_header_splits = html_splitter.split_text_from_url(url)

chunk_size = 500 # 텍스트를 분할할 청크의 크기를 지정
chunk_overlap = 30 # 분할된 청크 간의 중복되는 문자 수를 지정

# %%
splits = text_splitter.split_documents(html_header_splits)

for header in splits[80:85]:
    print(f'{header.page_content}')
    print(f'{header.metadata}', end='\n==========\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-cf783ece6629> in <cell line: 1>()
# ----> 1 splits = text_splitter.split_documents(html_header_splits)
#       2
#       3 for header in splits[80:85]:
#       4     print(f'{header.page_content}')
#       5     print(f'{header.metadata}', end='\n==========\n')
#
# NameError: name 'text_splitter' is not defined
